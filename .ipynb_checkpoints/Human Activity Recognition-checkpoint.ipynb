# %%
from pandas import Series, DataFrame
import pandas as pd

# %%
training=pd.read_csv("/home/myab/CourseraStuff/pml-training.csv", index_col=0)
# Out:
# /home/myab/anaconda3/lib/python3.4/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (11,14,19,22,25,70,73,86,87,89,90,94,97,100) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
training.head()
# Out:
#   user_name  raw_timestamp_part_1  raw_timestamp_part_2    cvtd_timestamp  \
# 1  carlitos            1323084231                788290  05/12/2011 11:23
# 2  carlitos            1323084231                808298  05/12/2011 11:23
# 3  carlitos            1323084231                820366  05/12/2011 11:23
# 4  carlitos            1323084232                120339  05/12/2011 11:23
# 5  carlitos            1323084232                196328  05/12/2011 11:23
#
#   new_window  num_window  roll_belt  pitch_belt  yaw_belt  total_accel_belt  \
# 1         no          11       1.41        8.07     -94.4                 3
# 2         no          11       1.41        8.07     -94.4                 3
# 3         no          11       1.42        8.07     -94.4                 3
# 4         no          12       1.48        8.05     -94.4                 3
# 5         no          12       1.48        8.07     -94.4                 3
#
# ...

# %%
training = training[training.columns[7:]]

# %%
training.head()
# Out:
#    pitch_belt  yaw_belt  total_accel_belt kurtosis_roll_belt  \
# 1        8.07     -94.4                 3                NaN
# 2        8.07     -94.4                 3                NaN
# 3        8.07     -94.4                 3                NaN
# 4        8.05     -94.4                 3                NaN
# 5        8.07     -94.4                 3                NaN
#
#   kurtosis_picth_belt kurtosis_yaw_belt skewness_roll_belt  \
# 1                 NaN               NaN                NaN
# 2                 NaN               NaN                NaN
# 3                 NaN               NaN                NaN
# 4                 NaN               NaN                NaN
# 5                 NaN               NaN                NaN
#
#   skewness_roll_belt.1 skewness_yaw_belt  max_roll_belt   ...    \
# 1                  NaN               NaN            NaN   ...
# 2                  NaN               NaN            NaN   ...
# ...

# %%
training = training.dropna(axis=1)

# %% [markdown]
# training.head()

# %%
training.head()
# Out:
#    pitch_belt  yaw_belt  total_accel_belt  gyros_belt_x  gyros_belt_y  \
# 1        8.07     -94.4                 3          0.00          0.00
# 2        8.07     -94.4                 3          0.02          0.00
# 3        8.07     -94.4                 3          0.00          0.00
# 4        8.05     -94.4                 3          0.02          0.00
# 5        8.07     -94.4                 3          0.02          0.02
#
#    gyros_belt_z  accel_belt_x  accel_belt_y  accel_belt_z  magnet_belt_x  \
# 1         -0.02           -21             4            22             -3
# 2         -0.02           -22             4            22             -7
# 3         -0.02           -20             5            23             -2
# 4         -0.03           -22             3            21             -6
# 5         -0.02           -21             2            24             -6
#
#     ...    gyros_forearm_x  gyros_forearm_y  gyros_forearm_z  accel_forearm_x  \
# ...
